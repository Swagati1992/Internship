# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#importing the dataset
df=pd.read_csv("Telecom_Customer_Churn.csv")

# %%
df        #displaying the imported dataset
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()    #Showing the first 5 rows of the dataset
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()       #Showing the last 5 rows of the dataset
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape     #It shows that our dataset is having 7043 rows and 21 columns
# Out:
# (7043, 21)

# %%
df.columns.tolist()    #Converted the names of columns into list
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.isnull().sum()      #Checking null values in each column
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.heatmap(df.isnull())     #Visulaizing the null values using heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see the heatmap is showing only one single colour which represents there are no missing values in the dataset.

# %%
df.info()             #To check the informtaion of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Here we can observe:
# i) all the respective columns
# ii) If there are any null values in any column
# iii) Data type of each column
# iv) Memory usage by the dataset

# %%
df.isnull().sum().sum()    #It shows the sum of total null values present in the dataset.
# Out:
# 0

# %%
df.head(4)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# ...

# %% [markdown]
# Here we can clearly see there are float values present in the TotalCharges column still the data type is object instead of float.

# %%
#Let us check why the TotalCharges columns is showing data ype as object
print(df['TotalCharges'].unique())
print("Sum of unique values =",df['TotalCharges'].nunique())
# Out:
# ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Sum of unique values = 6531

# %%
for i in df.columns:
    print(df[i].value_counts())
    print("\n")     #For space between printing of columns..
# Out:
# 7590-VHVEG    1
# 3791-LGQCY    1
# 6008-NAIXK    1
# 5956-YHHRX    1
# 5365-LLFYV    1
#              ..
# 9796-MVYXX    1
# 2637-FKFSY    1
# 1552-AAGRX    1
# 4304-TSPVK    1
# 3186-AJIEK    1
# Name: customerID, Length: 7043, dtype: int64
#
#
# Male      3555
# Female    3488
# Name: gender, dtype: int64
#
#
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
#
#
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
#
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64
#
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
#
# ...

# %% [markdown]
# Here we can see in the Total Charges column the value for 11 rows is blank, which means it is not null but have certain value and thats why the "Total Charges" column is showing data type "OBJECT".
# And also we can see there are no void spaces in any other column.

# %%
df.shape[0]     #Total rows in the dataset
# Out:
# 7043

# %%
df.shape[1]     #Total columns in dataset
# Out:
# 21

# %%
#Lets check which rows are having void/blank spaces
df.loc[df['TotalCharges']==" "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# Here we can cleraly see the rows having blank spaces in the "Total Charges" column

# %%
#Removing the void spaces
df['TotalCharges']=df['TotalCharges'].replace(" ",np.nan)     #Replace void spaces with null values

# %%
df['TotalCharges'].value_counts()
# Out:
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
# 19.65      8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6530, dtype: int64

# %% [markdown]
# Now we can see there are no blank spaces.

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %% [markdown]
# But here the data type is still "O" which means object

# %%
#Changing the datatype using type casting
df['TotalCharges']=df['TotalCharges'].astype(float)
df['TotalCharges'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Now the data type has been changed to float.

# %% [markdown]
# As we have appended nan values in Total Charges column inplace of void spaces lets check the value of null values in the dataset

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# We can see there are 11 rows having null values in Total Charges column.

# %%
#Replacing the null values
print("Mean =",df['TotalCharges'].mean())   #Checking the mean of the particular column
df['TotalCharges']=df['TotalCharges'].fillna(df['TotalCharges'].mean())   #Filling null values with the mean of the respective column
print("Total null values=",df['TotalCharges'].isnull().sum())
# Out:
# Mean = 2283.3004408418697
# Total null values= 0

# %% [markdown]
# Now the nan values has been replaced with mean value.

# %%
#Visulaizing presence of any null value in the dataset using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are no null values now in the dataset

# %%
#Separating numerical column
num_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!="object":
        num_col.append(i)
print("The numerical columns are:\n",num_col)
# Out:
# The numerical columns are:
#  ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
#Separating categorical columns
cat_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=="object":
        cat_col.append(i)
print("The categorical columns are:\n",cat_col)
# Out:
# The categorical columns are:
#  ['customerID', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %%
df.nunique()   #Checking the value of unique items
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.nunique().to_frame("No. of unique characters")
# Out:
#                   No. of unique characters
# customerID                            7043
# gender                                   2
# SeniorCitizen                            2
# Partner                                  2
# Dependents                               2
# tenure                                  73
# PhoneService                             2
# MultipleLines                            3
# InternetService                          3
# OnlineSecurity                           3
# OnlineBackup                             3
# DeviceProtection                         3
# TechSupport                              3
# StreamingTV                              3
# StreamingMovies                          3
# Contract                                 3
# PaperlessBilling                         2
# PaymentMethod                            4
# MonthlyCharges                        1585
# TotalCharges                          6531
# Churn                                    2

# %% [markdown]
# By creating this frame we can have a beautiful visulaization of unique values. "WE CAN SKIP THIS"

# %% [markdown]
# In the above data frame we can see customer ID is having same number of unique values as that of total rows in the dataset. So we can drop it.

# %%
#Dropping unnecessary data from the dataset
df.drop("customerID",axis=1,inplace=True)
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# After dropping the ID column our new dataset is having 7043 rows and 20 columns

# %% [markdown]
# # Description

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2265.000258
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    402.225000
# 50%         0.000000    29.000000       70.350000   1400.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# Here we can see from first row(count) its same as total number of rows in dataset so there are no missing values.
#
# Mean is more than median in "Tenure" and "Total Charges" column so we can say datas are skewed right.
#
# Mean is less than median in "Monthly Charges" so the column is skewed left.
#
# There is difference between 75% and max value in columns: "Tenure", "Monthly Charges" and "Total Charges", which means there are outliers present in these columns.

# %% [markdown]
# # Visualization of Data

# %% [markdown]
# Univariate Analysis on Categorical Data

# %%
cat_col.pop(0)   #Removing customerID
print(cat_col)
# Out:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']

# %%
print(df['Churn'].value_counts())
a=sns.countplot(x='Churn',data=df)
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# Here we can visulaize the churn rate is less as per the data record.

# %%
print(df["gender"].value_counts())
ax=sns.countplot(x='gender',data=df)
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %% [markdown]
# Here the no. of male customers is little higher than the female customers.

# %%
for i in cat_col:
    print(df[i].value_counts())
    print("\n")
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
#
#
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
#
#
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64
#
#
# Yes    6361
# No      682
# Name: PhoneService, dtype: int64
#
#
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64
#
#
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: InternetService, dtype: int64
#
#
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: OnlineSecurity, dtype: int64
#
#
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: OnlineBackup, dtype: int64
#
#
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: DeviceProtection, dtype: int64
#
#
# No                     3473
# Yes                    2044
# No internet service    1526
# ...

# %%
plt.figure(figsize=(20,20))
plotno=1
for col in cat_col:
    if plotno<=16:
        ax=plt.subplot(6,3,plotno)
        sns.countplot(df[col])
        plt.xlabel(col,fontsize=10)
    plotno+=1

# %% [markdown]
# Instead of plotting eacha and every column separately we can run a for loop and iterate and clearly visulaize in one stance.

# %% [markdown]
# Univariate analysis of Numerical Columns

# %%
print(num_col)
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
plt.figure(figsize=(10,6),facecolor='beige')
pltno=1
for col in num_col:
    if pltno<=4:
        ax=plt.subplot(2,2,pltno)
        sns.distplot(df[col],color='r')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    pltno+=1
plt.tight_layout()

# %% [markdown]
# Here we can see the "Total Charges" is having skewness.

# %% [markdown]
#  Bivariate Visualization

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.title("Comparison Monthly Charges and churn")
sns.stripplot(y="MonthlyCharges",x="Churn",data=df)
plt.show()

# %% [markdown]
# Here we can see Monthly Charges impact is normal on customers as both churn rate for yes and no is same.

# %%
plt.title("Comparison between Payment Method and Churn")
sns.stripplot(x="Churn",y="PaymentMethod",data=df)
plt.show()

# %%
plt.title("Tenure and Senior Citizen")
sns.stripplot(x="Churn",y="tenure",data=df)
plt.show()

# %%
plt.title("Comparison between tenure and total charges")
sns.scatterplot(x="tenure",y="TotalCharges",data=df,hue="Churn")
plt.show()

# %% [markdown]
# Here there is a strong positive correlation between the two variables

# %%
plt.title("Plotting churn and gender")
sns.barplot(x='gender',y='SeniorCitizen',data=df,palette="winter_r",hue="Churn")
plt.show()

# %%
sns.catplot(x='Churn',col='gender',data=df,kind="count",palette="winter_r")

# %%
sns.catplot(x='Churn',col='gender',data=df,kind='count',palette="husl")

# %%
sns.catplot(x='Churn',y="SeniorCitizen",data=df,kind='bar',palette='pastel')

# %%
sns.catplot(y='Churn',x="TotalCharges",data=df,kind='violin',palette='Set2')

# %%
print(num_col)
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']

# %%
sns.boxplot('MonthlyCharges',data=df,palette='Dark2')
# Out:
# <AxesSubplot:xlabel='MonthlyCharges'>

# %% [markdown]
# Multivariate Analysis

# %%
sns.pairplot(data=df,hue='Churn',palette='Dark2')
plt.show()

# %% [markdown]
# From above graph we can see that there is skewness present in "Total Charges" column

# %% [markdown]
# # Removing Skewness

# %% [markdown]
# From our above findings "Total Charges" column is having skewness.
# Lets remove it so that the data can be normally distributed.

# %%
df.skew()
# Out:
# SeniorCitizen     1.833633
# tenure            0.239540
# MonthlyCharges   -0.220524
# TotalCharges      0.962394
# dtype: float64

# %%
df['TotalCharges']=np.cbrt(df['TotalCharges'])      #Skewness removed using numpy cuberoot method

# %%
df.skew()        #No skewness present
# Out:
# SeniorCitizen     1.833633
# tenure            0.239540
# MonthlyCharges   -0.220524
# TotalCharges      0.011168
# dtype: float64

# %%
#Lets visulaize the skewness
sns.distplot(df['TotalCharges'],color='g')
plt.show()

# %% [markdown]
# We can clearly see the difference, this column is almost normally distributed now.

# %% [markdown]
# # Detecting Outliers

# %%
plt.figure(figsize=(10,7),facecolor='m')
pltno=1
for i in num_col:
    if pltno<=4:
        ax=plt.subplot(2,2,pltno)
        sns.boxplot(df[i],palette="Dark2")
        plt.xlabel(i,fontsize=12)
    pltno+=1

# %% [markdown]
# As we can see its almost a clean dataset.
#
# Here SeniorCitizen is a categorical column but due to presence of some numerical values it is behaving numerical, so being a categorical column no need of removing the outliers.

# %% [markdown]
# # Encoding Categorical Columns

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# Here we can see object data type is present and we cannot consider object data for prediction of models, so we need to encode it

# %%
#Import the library
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in cat_col:
    df[i]=le.fit_transform(df[i])
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %% [markdown]
# Here we can see all our data has been convered into numeric form.

# %%
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %% [markdown]
# Here we can see,No missing values, Almost no outliers so it can be considered for further prediction

# %% [markdown]
# # Correlation between the target and feature variable

# %%
cor=df.corr()
cor
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %% [markdown]
# Its hard to read the data in the tabular format lets visualize using heatmap

# %%
plt.figure(figsize= (20,15))
sns.heatmap(df.corr(),annot=True, linewidth=0.1, linecolor='r',cmap="Blues_r")
plt.show()

# %%
cor['Churn'].sort_values(ascending=False)
# Out:
# Churn               1.000000
# MonthlyCharges      0.193356
# PaperlessBilling    0.191825
# SeniorCitizen       0.150889
# PaymentMethod       0.107062
# MultipleLines       0.038037
# PhoneService        0.011942
# gender             -0.008612
# StreamingTV        -0.036581
# StreamingMovies    -0.038492
# InternetService    -0.047291
# Partner            -0.150448
# Dependents         -0.164221
# DeviceProtection   -0.178134
# OnlineBackup       -0.195525
# TotalCharges       -0.233781
# TechSupport        -0.282492
# OnlineSecurity     -0.289309
# tenure             -0.352229
# Contract           -0.396713
# Name: Churn, dtype: float64

# %%
#Now lets separate the data as feature(x) and target(y)
x=df.iloc[:,0:-1]
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int32

# %% [markdown]
# # Checking and removing biasness

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Scaling the feature
st=StandardScaler()
xf=st.fit_transform(x)
x=pd.DataFrame(data=xf,columns=x.columns)
x.head()
# Out:
#      gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# 0 -1.009559      -0.439916  1.034530   -0.654012 -1.277445     -3.054010
# 1  0.990532      -0.439916 -0.966622   -0.654012  0.066327      0.327438
# 2  0.990532      -0.439916 -0.966622   -0.654012 -1.236724      0.327438
# 3  0.990532      -0.439916 -0.966622   -0.654012  0.514251     -3.054010
# 4 -1.009559      -0.439916 -0.966622   -0.654012 -1.236724      0.327438
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0       0.062723        -1.183234       -0.918838      1.242550
# 1      -0.991588        -1.183234        1.407321     -1.029919
# 2      -0.991588        -1.183234        1.407321      1.242550
# 3       0.062723        -1.183234        1.407321     -1.029919
# 4      -0.991588         0.172250       -0.918838     -1.029919
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %% [markdown]
# # Reducing Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values          Features
# 0     1.001696            gender
# 1     1.149704     SeniorCitizen
# 2     1.462974           Partner
# 3     1.383950        Dependents
# 4    12.357252            tenure
# 5     1.622391      PhoneService
# 6     1.398354     MultipleLines
# 7     1.870013   InternetService
# 8     1.256219    OnlineSecurity
# 9     1.192694      OnlineBackup
# 10    1.288549  DeviceProtection
# 11    1.312649       TechSupport
# 12    1.445353       StreamingTV
# 13    1.443816   StreamingMovies
# 14    2.519511          Contract
# 15    1.203384  PaperlessBilling
# 16    1.180762     PaymentMethod
# 17    5.384672    MonthlyCharges
# 18   16.702806      TotalCharges

# %% [markdown]
# VIF value within 10 is acceptable and as we can see there is no multicollinaerity

# %% [markdown]
# # Oversampling

# %%
y.value_counts()       #Checking if the set is balanced or imbalanced
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# As we can see our target variable is not balanced as cat 0 is having 5174 data and cat 1 is having 1869 data.

# %%
from imblearn.over_sampling import SMOTE

# %%
#Balancing the dataset
smt=SMOTE()
x,y=smt.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0    5174
# 1    5174
# Name: Churn, dtype: int64

# %% [markdown]
# Now we can see our target bariable is having equal number of data in each category

# %% [markdown]
# # Finding the best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier                #Importing necessary liabraries
from sklearn.metrics import accuracy_score

# %%
max_accu=0
max_rs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>max_accu:
        max_accu=acc
        max_rs=i
print("Best Accuracy is",max_accu,"at random state",max_rs)
# Out:
# Best Accuracy is 0.8682769726247987 at random state 270

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=270)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print("Model=",dtc)
print("Accuracy Score =",accuracy_score(y_test,dtcpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,dtcpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,dtcpred))
# Out:
# Model= DecisionTreeClassifier()
# Accuracy Score = 0.7822866344605475
#
#
#  Confusion Matrix
#  [[1236  325]
#  [ 351 1193]]
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79      1561
#            1       0.79      0.77      0.78      1544
#
#     accuracy                           0.78      3105
#    macro avg       0.78      0.78      0.78      3105
# weighted avg       0.78      0.78      0.78      3105

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfcpred=rfc.predict(x_test)
print("Model =",rfc)
print("Accuracy Score =",accuracy_score(y_test,rfcpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,rfcpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,rfcpred))
# Out:
# Model = RandomForestClassifier()
# Accuracy Score = 0.863768115942029
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      1561
#            1       0.85      0.87      0.86      1544
#
#     accuracy                           0.86      3105
#    macro avg       0.86      0.86      0.86      3105
# weighted avg       0.86      0.86      0.86      3105
#
#
#
#  Confusion Matrix
#  [[1332  229]
#  [ 194 1350]]

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
gnbpred=gnb.predict(x_test)
print("Model =",gnb)
print("Accuracy Score =",accuracy_score(y_test,gnbpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,gnbpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,gnbpred))
# Out:
# Model = GaussianNB()
# Accuracy Score = 0.7697262479871175
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76      1561
#            1       0.75      0.80      0.78      1544
#
#     accuracy                           0.77      3105
#    macro avg       0.77      0.77      0.77      3105
# weighted avg       0.77      0.77      0.77      3105
#
#
#
#  Confusion Matrix
#  [[1156  405]
#  [ 310 1234]]

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knnpred=knn.predict(x_test)
print("Model =",knn)
print("Accuracy Score =",accuracy_score(y_test,knnpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,knnpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,knnpred))
# Out:
# Model = KNeighborsClassifier()
# Accuracy Score = 0.7942028985507247
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77      1561
#            1       0.74      0.90      0.81      1544
#
#     accuracy                           0.79      3105
#    macro avg       0.81      0.79      0.79      3105
# weighted avg       0.81      0.79      0.79      3105
#
#
#
#  Confusion Matrix
#  [[1076  485]
#  [ 154 1390]]

# %%
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
abcpred=abc.predict(x_test)
print("Model =",abc)
print("Accuracy Score =",accuracy_score(y_test,abcpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,abcpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,abcpred))
# Out:
# Model = AdaBoostClassifier()
# Accuracy Score = 0.8225442834138487
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.79      0.82      1561
#            1       0.80      0.85      0.83      1544
#
#     accuracy                           0.82      3105
#    macro avg       0.82      0.82      0.82      3105
# weighted avg       0.82      0.82      0.82      3105
#
#
#
#  Confusion Matrix
#  [[1238  323]
#  [ 228 1316]]

# %%
sv=SVC()
sv.fit(x_train,y_train)
svpred=sv.predict(x_test)
print("Model =",sv)
print("Accuracy Score =",accuracy_score(y_test,svpred))
print("\n")
print(" Classification Report\n",classification_report(y_test,svpred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,svpred))
# Out:
# Model = SVC()
# Accuracy Score = 0.8167471819645733
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81      1561
#            1       0.80      0.84      0.82      1544
#
#     accuracy                           0.82      3105
#    macro avg       0.82      0.82      0.82      3105
# weighted avg       0.82      0.82      0.82      3105
#
#
#
#  Confusion Matrix
#  [[1233  328]
#  [ 241 1303]]

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(rfc,x,y)
print(rfc)
print(score)
print(score.mean())
print("Difference between accuracy and CV score is",accuracy_score(y_test,rfcpred)-score.mean())
# Out:
# RandomForestClassifier()
# [0.77487923 0.79275362 0.88743961 0.89366844 0.89946834]
# 0.8496418489643529
# Difference between accuracy and CV score is 0.01412626697767605

# %%
score1=cross_val_score(dtc,x,y)
print(dtc)
print(score1)
print(score1.mean())
print("The difference between acc and CV score is",accuracy_score(y_test,dtcpred)-score1.mean())
# Out:
# DecisionTreeClassifier()
# [0.71062802 0.72995169 0.80772947 0.84098598 0.8260029 ]
# 0.7830596124525139
# The difference between acc and CV score is -0.0007729779919664059

# %%
score2=cross_val_score(sv,x,y)
print(sv)
print(score2)
print(score2.mean())
print("The difference between acc and CV is",accuracy_score(y_test,svpred)-score2.mean())
# Out:
# SVC()
# [0.78357488 0.77971014 0.81594203 0.82310295 0.82310295]
# 0.8050865899416975
# The difference between acc and CV is 0.011660592022875838

# %% [markdown]
# From above we can say that model SVC is having the least difference between the accuracy score and mean so we will continue with this model.

# %% [markdown]
# # Hyper_Parameter Tuning

# %%
# Import the library
from sklearn.model_selection import GridSearchCV

# %%
parameters={"C":[1,5,10,12],"kernel":['linear', 'poly', 'rbf', 'sigmoid'],"gamma":['scale','auto'],
            "max_iter":[10,20,30,40]}
grid=GridSearchCV(estimator=sv,param_grid=parameters)
grid.fit(x,y)
print("GRID :",grid)
print("SCORE :",grid.best_score_)
print(grid.best_params_)
# Out:
# GRID : GridSearchCV(estimator=SVC(C=1, gamma='auto', max_iter=40),
#              param_grid={'C': [1, 5, 10, 12], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
#                          'max_iter': [10, 20, 30, 40]})
# SCORE : 0.682750751255595
# {'C': 1, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': 40}

# %%
#Applying the parameters received after hyper parameter tuning
sv=SVC(C=1,gamma='auto',kernel='rbf',max_iter=40)
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print("Accuracy Score :",accuracy_score(y_test,pred))
# Out:
# Accuracy Score : 0.6235104669887278

# %%
parameters={'criterion':['gini','entropy','log_loss'],
           'splitter':['best','random'], 'max_depth':[0,2,5,7],'max_leaf_nodes':[5,10,15,20]}
grid=GridSearchCV(estimator=dtc,param_grid=parameters)
grid.fit(x,y)
print("GRID :",grid)
print("SCORE :",grid.best_score_)
print(grid.best_params_)
# Out:
# GRID : GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [0, 2, 5, 7],
#                          'max_leaf_nodes': [5, 10, 15, 20],
#                          'splitter': ['best', 'random']})
# SCORE : 0.79619667369473
# {'criterion': 'gini', 'max_depth': 7, 'max_leaf_nodes': 20, 'splitter': 'best'}

# %%
#Applying the parameters
dtc=DecisionTreeClassifier(criterion='gini',max_depth=7,max_leaf_nodes=20,splitter='best')
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print("Model =",dtc)
print("Accuracy Score =",accuracy_score(y_test,pred))
print("\n")
print(" Classification Report\n",classification_report(y_test,pred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,pred))
# Out:
# Model = DecisionTreeClassifier(max_depth=7, max_leaf_nodes=20)
# Accuracy Score = 0.8009661835748793
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      1561
#            1       0.80      0.80      0.80      1544
#
#     accuracy                           0.80      3105
#    macro avg       0.80      0.80      0.80      3105
# weighted avg       0.80      0.80      0.80      3105
#
#
#
#  Confusion Matrix
#  [[1256  305]
#  [ 313 1231]]

# %% [markdown]
# Here we can clearly see previously before applying the hyper tuning parameters score of Decision Tree Classifier was 0.78 and now its 0.80.

# %%
parameters={'criterion':['gini','entropy','log_loss'],'n_estimators':[100,120,126,180,200],'max_depth':[2,7,6,20,25]}
grid=GridSearchCV(estimator=rfc,param_grid=parameters)
grid.fit(x,y)
print("GRID :",grid)
print("SCORE :",grid.best_score_)
print(grid.best_params_)
# Out:
# GRID : GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [2, 7, 6, 20, 25],
#                          'n_estimators': [100, 120, 126, 180, 200]})
# SCORE : 0.8522511516917552
# {'criterion': 'gini', 'max_depth': 25, 'n_estimators': 100}

# %%
rfc=RandomForestClassifier(criterion='gini',max_depth=25,n_estimators=100)
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
print("Model =",rfc)
print("Accuracy Score =",accuracy_score(y_test,pred))
print("\n")
print(" Classification Report\n",classification_report(y_test,pred))
print("\n")
print(" Confusion Matrix\n",confusion_matrix(y_test,pred))
# Out:
# Model = RandomForestClassifier(max_depth=25)
# Accuracy Score = 0.8669887278582931
#
#
#  Classification Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87      1561
#            1       0.86      0.87      0.87      1544
#
#     accuracy                           0.87      3105
#    macro avg       0.87      0.87      0.87      3105
# weighted avg       0.87      0.87      0.87      3105
#
#
#
#  Confusion Matrix
#  [[1347  214]
#  [ 199 1345]]

# %% [markdown]
# As Random Forest Classifier is giving the highesr accuracy score of 87% we will proceed with this model.

# %%
Final_model=rfc
Final_model
# Out:
# RandomForestClassifier(max_depth=25)

# %% [markdown]
# # ROC AUC

# %%
#Importing necessary libraries
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
#Plotting ROC AUC
y_pred_prob=Final_model.predict(x_test)
fpr, tpr, thresholds=roc_curve(y_test,y_pred_prob)

plt.plot([0,1],[0,1],"k--")
plt.plot(fpr, tpr, label=rfc,color='darkred',lw=7,linestyle="--")
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %%
#Lets check the AUC score for best model
auc_score=roc_auc_score(y_test,Final_model.predict(x_test))
print("AUC Score is:",auc_score)
# Out:
# AUC Score is: 0.8670111908468399

# %% [markdown]
# Here the auc score is 87% which means our classifier is able to differentiate between positive class and negative class and it is working well on unseen data i.e., on test data.

# %%
#Finally its time to save our model
import joblib
joblib.dump(Final_model,"Telecom Customer Churn.pkl")
# Out:
# ['Telecom Customer Churn.pkl']

# %%
#Predicting the saved model
saved_model=joblib.load("Telecom Customer Churn.pkl")
pred=saved_model.predict(x_test)
pred
# Out:
# array([0, 1, 1, ..., 0, 1, 0])

# %%
#Creating dataframe for predicted and actual result from the best saved model
actual=np.array(y_test)
ds=pd.DataFrame({"Predicted Value":pred,"Actual Value":actual})
ds
# Out:
#       Predicted Value  Actual Value
# 0                   0             1
# 1                   1             0
# 2                   1             1
# 3                   1             1
# 4                   1             1
# ...               ...           ...
# 3100                0             0
# 3101                1             1
# 3102                0             0
# 3103                1             1
# 3104                0             0
#
# [3105 rows x 2 columns]
